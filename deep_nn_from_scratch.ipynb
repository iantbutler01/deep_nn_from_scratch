# %% [markdown]
# ### Why?
#
# Implementing something from first principles is a good way to make sure you understand at a deep level how that thing works, and trying to build it from scratch will quickly make you aware of what parts you still don't understand.
#
# ### Backstory
#
# I started working with ML and more precisely DL in 2016, my personal interests are NLP and Reinforcement Learning.
#
# From 2016-2019 I worked on everything from Seq2Seq models to ConvNets focused on text prediction tasks. I was particularly inerested in the Attention Mechanism.
#
# I wrote a few papers as part of independent studies and as part of a stint as a research assistant in 2018. Prior to that I had been working fulltime as a SWE taking a break from college. From the end of 2018 to the start of 2020 I kept on ML as a hobby. From 2020-2021 I was working on my startup for better code search and documentation which ultimately didn't go anywhere. From Sep 2021 to June of 2022 I had burnt out and was just doing my day job and avoiding comptuers outside of that.
#
# In 2020 I had used BERT and various flavors like RoBERTa for semantic search but I did not take the time to understand the architecture and more generally started getting rusty, that continued through my period of burn out.
#
# Now that I'm not burnt out and working in a job that I enjoy I've been taking the time to get back into working on ML related projects and as part of that I'm doing a couple different refresher courses.
#
# As of this work I've just finished Lesson 5 of "Practical Deep Learning for Coders" by FastAI and wanted to implement a full NN from scratch, from memory, to test my fundamentals. Below is the result of that.

# %%
# !pip install jupyter_contrib_nbextensions
# !pip install autopep8
# !jupyter nbextension enable code_prettify/code_prettify
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /home/crow/venvs/mlwork/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: tornado in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (6.2)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: lxml in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (4.9.2)
# Requirement already satisfied: traitlets>=4.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (5.8.1)
# Requirement already satisfied: ipython-genutils in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: nbconvert>=6.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (7.2.9)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-core in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (5.1.5)
# Requirement already satisfied: notebook>=6.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (6.5.2)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter_contrib_nbextensions) (0.6.1)
# Requirement already satisfied: setuptools in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (59.6.0)
# Requirement already satisfied: pyyaml in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0)
# Requirement already satisfied: packaging in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.0)
# Requirement already satisfied: jupyterlab-pygments in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: bleach in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.14.0)
# Requirement already satisfied: tinycss2 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: markupsafe>=2.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.2)
# Requirement already satisfied: defusedxml in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.11.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.2)
# Requirement already satisfied: nbformat>=5.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.7.3)
# Requirement already satisfied: jinja2>=3.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter-core->jupyter_contrib_nbextensions) (2.6.2)
# Requirement already satisfied: ipykernel in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (6.20.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.5.6)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (7.4.1)
# Requirement already satisfied: argon2-cffi in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: prometheus-client in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.16.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.4.8)
# Requirement already satisfied: pyzmq>=17 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (25.0.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: entrypoints in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter-client>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.8.2)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.23.5)
# Requirement already satisfied: jsonschema>=2.6 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.17.3)
# Requirement already satisfied: fastjsonschema in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: ptyprocess in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.3.2.post1)
# Requirement already satisfied: webencodings in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (8.8.0)
# Requirement already satisfied: psutil in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.4)
# Requirement already satisfied: debugpy>=1.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.6)
# Requirement already satisfied: jedi>=0.16 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.2)
# Requirement already satisfied: decorator in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: backcall in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pickleshare in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: stack-data in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.36)
# Requirement already satisfied: attrs>=17.4.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.1->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.19.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.6.2)
# Requirement already satisfied: websocket-client in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.4.2)
# Requirement already satisfied: cffi>=1.0.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (1.15.1)
# Requirement already satisfied: idna>=2.8 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: pycparser in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.1)
# Requirement already satisfied: pure-eval in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (1.2.0)
# Requirement already satisfied: autopep8 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: tomli in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from autopep8) (2.0.1)
# Requirement already satisfied: pycodestyle>=2.10.0 in /home/crow/venvs/mlwork/lib/python3.10/site-packages (from autopep8) (2.10.0)
# Enabling notebook extension code_prettify/code_prettify...
#       - Validating: OK

# %%
from torch.nn import functional as F
from torch import Tensor
import torch
from abc import ABC, abstractmethod


class Dataset():

    def __init__(self, train, valid, test=None):
        self._train_set = train
        self._valid_set = valid

    def train(self):
        return self._train_set()

    def valid(self):
        return self._valid_set()


class Optimizer():

    def __init__(self, model_params, lr):
        self.model_params = model_params
        self.lr = lr

    def step(self):
        for param in self.model_params:
            param.data -= param.grad.data * self.lr

    def zero_grad(self):
        for param in self.model_params:
            param.grad = None

            
class Model():

    def __init__(self, layers=[]):
        self.layers = []
        self.params = []

        for layer in layers:
            self._register_layer(layer)

    def parameters(self):
        return self.params

    def _register_layer(self, layer):
        if self.layers:
            layer.set_output_shape(self.layers[-1])
            layer.create_bias(self.layers[-1])
        else:
            layer.set_output_shape(None)
                    
        if layer.parameters:
            self.params.extend(layer.parameters)
            
        self.layers.append(layer)

    def infer(self, x):
        l1 = self.layers[0]
        o = l1.call(x)
        for layer in self.layers[1:]:
            o = layer.call(o)

        return o

# %%
import torchvision

from torchvision import transforms

transform = transforms.Compose([
    transforms.ToTensor(),
    lambda x: x.view(x.shape[0], -1),
    lambda x: x.squeeze()
])

mnist_data = torchvision.datasets.MNIST("./data/mnist/train",
                                        train=True,
                                        download=True,
                                        transform=transform)
test_mnist_data = torchvision.datasets.MNIST("./data/mnist/test",
                                             train=False,
                                             download=True,
                                             transform=transform)

data_loader = torch.utils.data.DataLoader(mnist_data,
                                          batch_size=1024,
                                          shuffle=True,
                                          num_workers=12)

test_data_loader = torch.utils.data.DataLoader(test_mnist_data,
                                               batch_size=1024,
                                               shuffle=True,
                                               num_workers=12)


def train_fn():
    return iter(data_loader)


def valid_fn():
    return iter(test_data_loader)


ds = Dataset(train=train_fn, valid=valid_fn)

# %%
class Layer(ABC):

    def __init__(self):
        self.parameters = []
        
    @abstractmethod
    def set_output_shape(self, prev_layer):
        pass
    
    @abstractmethod
    def create_bias(self, prev_layer):
        pass

    @abstractmethod
    def call(self, layer):
        pass
    
class Input(Layer):
    def __init__(self, r, c):
        super().__init__()
        self.shape = (r, c)
         
    def create_bias(self, prev_layer):
        pass
    
    def set_output_shape(self, prev_layer):
        self.output_shape = self.shape
    
    def call(self, layer):
        return layer
    
class NonLinear(Layer):

    def __init__(self):
        super().__init__()
    
    def create_bias(self, prev_layer):
        pass
    
    def set_output_shape(self, prev_layer):
        self.output_shape = prev_layer.output_shape

    @abstractmethod
    def func(self, x):
        pass

    def a(self, zed):
        return self.func(zed)

    def call(self, layer):
        return self.a(layer)


class ReLu(NonLinear):

    def func(self, x):
        return torch.relu(x)


class LogSoftmax(NonLinear):

    def func(self, x):
        return torch.log(torch.exp(x) / torch.sum(torch.exp(x)))

# %%
class Linear(Layer):
    def __init__(self, r, c):
        self.shape = (r, c)
        self.w = torch.zeros(r, c, requires_grad=True)
        init_y = torch.div(1, torch.sqrt(torch.tensor(r)))
        #init_y = 0.01
        self.w.data.uniform_(-init_y, init_y)
        self.b = None
       
        self.parameters = [self.w]

    def zed(self, a_prev):
        z = a_prev @ self.w + self.b
        
        return z
    
    def set_output_shape(self, prev_layer):
        self.output_shape = (prev_layer.output_shape[0], self.shape[1])
        
    def create_bias(self, prev_layer):
        self.b = torch.zeros(self.output_shape[0], self.output_shape[1], requires_grad=True)
        init_y = torch.div(1, torch.sqrt(torch.tensor(self.output_shape[0])))
        #init_y = 0.01
        self.b.data.uniform_(-init_y, init_y)
        self.parameters.append(self.b)

    def call(self, layer):
        return self.zed(layer)

# %%
model = Model([
    Input(1024, 28 * 28),
    Linear(28 * 28, 128),
    ReLu(),
    Linear(128, 64),
    ReLu(),
    Linear(64, 10),
    LogSoftmax()
])

# %%
class Learner():

    def __init__(self, model, optimizer, loss, dataset, metric):
        self.opt = optimizer
        self.loss = loss
        self.dataset = dataset
        self.model = model
        self.metric = metric
        
    def _validate(self):
        accs = []
        
        for (xb, yb) in self.dataset.valid():
            if xb.shape[0] < model.layers[0].shape[0]:
                    continue
            preds = self.model.infer(xb)
            
            accs.append(self.metric(preds, yb))
        
        return round(torch.stack(accs).mean().item(), 4)

    def fit(self, epochs=10, lr=0.01):
        loss_fn = self.loss
        opt = self.opt(self.model.parameters(), lr)
        for _ in range(0, epochs):
            running_loss = 0
            total_batches = 0
            for (x, y) in self.dataset.train():
                if x.shape[0] < model.layers[0].shape[0]:
                    continue
                opt.zero_grad()
                out = self.model.infer(x)
                loss = loss_fn(out, y)
                loss.backward()
                opt.step()
                running_loss += loss.item()
                total_batches += 1
            print(running_loss/(total_batches))
            valid = self._validate()
            print(f"Running metric on validation set after epoch: {valid}")

# %%
opt = Optimizer

loss = torch.nn.NLLLoss()

def mnist_acc(preds, targets):
    return (preds.argmax(-1) == targets.squeeze()).float().mean()

learner = Learner(model, opt, loss, ds, mnist_acc)

learner.fit(epochs=20)
# Out:
# 9.229732825838287
# Running metric on validation set after epoch: 0.1627
# 9.212893338039004
# Running metric on validation set after epoch: 0.3114
# 9.191571449411326
# Running metric on validation set after epoch: 0.4355
# 9.162451711194269
# Running metric on validation set after epoch: 0.5101
# 9.123250566679856
# Running metric on validation set after epoch: 0.5642
# 9.06949758529663
# Running metric on validation set after epoch: 0.6144
# 8.99477088862452
# Running metric on validation set after epoch: 0.6521
# 8.89283456473515
# Running metric on validation set after epoch: 0.6897
# 8.760742220385321
# Running metric on validation set after epoch: 0.7119
# 8.604740093494284
# Running metric on validation set after epoch: 0.7303
# 8.443349706715551
# Running metric on validation set after epoch: 0.7446
# 8.295679848769616
# Running metric on validation set after epoch: 0.7643
# 8.176097639675799
# Running metric on validation set after epoch: 0.7885
# 8.086660450902478
# Running metric on validation set after epoch: 0.8024
# 8.018759883683304
# Running metric on validation set after epoch: 0.814
# 7.966604948043823
# Running metric on validation set after epoch: 0.822
# 7.922079201402335
# Running metric on validation set after epoch: 0.8301
# 7.884528324521821
# Running metric on validation set after epoch: 0.8398
# 7.851161899237797
# Running metric on validation set after epoch: 0.8423
# 7.821572871043764
# Running metric on validation set after epoch: 0.8449
